# %%
import pandas as pd
import numpy as np
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("C:\\Users\\erinb\\OneDrive\\Documents\\Georgetown\\DSAN 5000\\dsan-5000-project-ebevec\\data\\01-modified-data\\data_clean2.csv")
df = df.iloc[:, 1:23]
df = df.drop(['GDP_2019', 'GDP_2020'], axis = 1)
df.head()
# Out:
#      Country  pop_2019 pop_2020  unemployment_2019  unemployment_2020  \
# 0    Albania     2.881    2.878             11.470             11.675
# 1    Algeria    43.424   43.851             11.383                NaN
# 2     Angola    32.354   33.428                NaN                NaN
# 3  Argentina    44.939   45.388              9.825             11.550
# 4    Armenia     2.963    2.962             18.300             18.200
#
#    hf_score_2019  hf_rank_2019  pf_religion_2019  pf_expression_2019  \
# 0           8.07            42          9.737500            6.248600
# 1           5.08           155          5.236667            4.586654
# 2           5.96           127          6.736667            5.500711
# 3           7.33            75          9.859375            8.205444
# 4           8.32            34          8.338542            7.617444
#
#    ef_score_2019  pf_ss_2019  hf_score_2020  hf_rank_2020  pf_religion_2020  \
# 0           7.79    9.350083           7.67            47          9.757500
# 1           4.86    8.952936           5.13           154          5.417292
# 2           5.55    8.463164           5.97           122          6.746042
# 3           5.44    8.404363           6.99            74          9.873750
# 4           7.98    9.264917           8.14            26          8.389792
#
#    pf_expression_2020  ef_score_2020  pf_ss_2020  Year  \
# 0            6.106867           7.64    9.249726  2020
# 1            4.395414           5.12    8.840074  2020
# 2            5.597544           5.91    8.473782  2020
# 3            8.389844           4.87    8.504898  2020
# 4            7.580944           7.84    9.395818  2020
#
#    Learning.Adjusted.Years.of.School          regime_2019
# 0                           8.953018  electoral autocracy
# 1                           7.091553  electoral autocracy
# 2                           4.234978  electoral autocracy
# 3                           8.411310  electoral democracy
# 4                           7.994621  electoral democracy

# %%
x = df.iloc[:,1:20]
x = x.apply(pd.to_numeric, errors = 'coerce')
x = x.replace(np.NaN, 0)
y = df.iloc[:,19]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=123)

# %%
model = MultinomialNB()
model.fit(x_train, y_train)

model.score(x_test, y_test)
# Out:
# 0.5925925925925926

# %%
y_pred = model.predict(x_test)
confusion_matrix(y_pred, y_test)
# Out:
# array([[1, 1, 0, 0],
#        [1, 4, 2, 0],
#        [0, 3, 4, 2],
#        [0, 0, 2, 7]], dtype=int64)
